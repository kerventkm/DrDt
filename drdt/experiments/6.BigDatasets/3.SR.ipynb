# %% [markdown]
# # Chess

# %%
# Libraries
import itertools
from importlib import resources
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo
import random
import time

from drdt.helper_functions import DecisionRuleCreatorFromDecisionTable, Reduction, R_SR, R_AD, SAlphaStep, SPlus, SMax, NCover, NGreedy
from drdt.algorithms import DynamicProgrammingAlgorithms, A_C_N, A_C_G
from drdt.helper_functions import DecisionRuleCreatorFromDecisionTable
pd.options.mode.chained_assignment = None

# %%
problems = ['AR', 'EAR', 'SR', 'ESR', 'AD', 'EAD']
dataset_name = "Chess"

DP = []
NC = []
NCgreedy = []
Gr = []

# %% [markdown]
# # Loading Data

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_chess') as dataset_path:
    S = pd.read_csv(dataset_path).applymap(lambda x: str(x) if pd.notnull(x) else x)
S = S.dropna(axis=1, how='all') # Drop the columns with all None
S
# Out:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_67526/42485626.py:1: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('datasets.DecisionRuleSystems', 'DRS_chess') as dataset_path:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_67526/42485626.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   S = pd.read_csv(dataset_path).applymap(lambda x: str(x) if pd.notnull(x) else x)
#      bkblk bknwy bkon8 bkona bkspr bkxbq bkxcr bkxwp blxwp bxqsq  ... skrxp  \
# 0      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 3128   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3129     t   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3130     t   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3131     t   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
# 3132     t   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN
#
#      spcop stlmt thrsk wkcti wkna8 wknck wkovl wkpos  class
# 0      NaN   NaN   NaN     t   NaN   NaN   NaN   NaN  nowin
# 1      NaN   NaN   NaN     t   NaN   NaN   NaN   NaN  nowin
# 2      NaN   NaN   NaN     t   NaN   NaN   NaN   NaN  nowin
# 3      NaN   NaN   NaN     t   NaN   NaN   NaN   NaN  nowin
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    won
# ...    ...   ...   ...   ...   ...   ...   ...   ...    ...
# 3128   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  nowin
# 3129   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    won
# 3130   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    won
# 3131   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    won
# 3132   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    won
#
# [3133 rows x 36 columns]

# %% [markdown]
# # Dataset Analyses

# %%
n = len(S.columns)-1
print(f"Number of features  = {n}")
# Out:
# Number of features  = 35

# %%
print(f"Does # of features = d  = {not S.dropna().empty}")
# Out:
# Does # of features = d  = False

# %%
# Count non-NaN values for each row
non_nan_counts = S.count(axis=1)

# Find the index
max_non_nan_row_index = non_nan_counts.idxmax()

# Retrieve the row
max_non_nan_row = S.loc[max_non_nan_row_index]

# Number of non-NaN values in the row
max_non_nan_count = non_nan_counts[max_non_nan_row_index]

d = max_non_nan_count - 1

print(f"d = {d}") # remove 1 because of last class column
# Out:
# d = 11

# %% [markdown]
# # Combinations

# %%
column_values_extension = []

for column in S.columns[:-1]:  # ignoring class column
    unique_values_extension = list(S[column].dropna().unique()) + ['*']
    random.shuffle(unique_values_extension)  # Shuffling the unique values list
    column_values_extension.append(unique_values_extension)

extended_combinations_iterator = itertools.product(*column_values_extension)

extended_combinations = list(itertools.islice(extended_combinations_iterator, 100000))

# %% [markdown]
# # Node Cover

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="cover")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("NC EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NC.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [1:53:14<00:00, 14.72it/s]
# NC EAR
# (Max Depth, Min Depth, Average Depth) = (35, 35, 35.0)
# Running time = 6794.0304479599

# %% [markdown]
# # Node Cover Greedy

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("NCgreedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NCgreedy.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [4:05:05<00:00,  6.80it/s]
# NCgreedy EAR
# (Max Depth, Min Depth, Average Depth) = (35, 35, 35.0)
# Running time = 14705.254941940308

# %% [markdown]
# # Greedy

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_G(C="EAR")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("Greedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
Gr.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [1:15:53<00:00, 21.96it/s]
# Greedy EAR
# (Max Depth, Min Depth, Average Depth) = (35, 34, 34.8515)
# Running time = 4553.14670085907

# %% [markdown]
# # Molecular Biology

# %%
# Libraries
import itertools
from importlib import resources
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo
import random
import time

from drdt.helper_functions import DecisionRuleCreatorFromDecisionTable, Reduction, R_SR, R_AD, SAlphaStep, SPlus, SMax, NCover, NGreedy
from drdt.algorithms import DynamicProgrammingAlgorithms, A_C_N, A_C_G
from drdt.helper_functions import DecisionRuleCreatorFromDecisionTable
pd.options.mode.chained_assignment = None

# %%
problems = ['AR', 'EAR', 'SR', 'ESR', 'AD', 'EAD']
dataset_name = "MolecularBiology"

DP = []
NC = []
NCgreedy = []
Gr = []

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_molecular_biology') as dataset_path:
    S = pd.read_csv(dataset_path).applymap(lambda x: str(x) if pd.notnull(x) else x)
S = S.dropna(axis=1, how='all') # Drop the columns with all None
S
# Out:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_67526/4126655002.py:1: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('datasets.DecisionRuleSystems', 'DRS_molecular_biology') as dataset_path:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_67526/4126655002.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   S = pd.read_csv(dataset_path).applymap(lambda x: str(x) if pd.notnull(x) else x)
#      Base1 Base2 Base3 Base4 Base5 Base6 Base7 Base8 Base9 Base10  ... Base52  \
# 0      NaN     A   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN
# 1      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN
# 2      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN
# 3      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN      T  ...    NaN
# 4      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...    ...  ...    ...
# 3000     T   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN
# 3001     T   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN
# 3002   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN
# 3003     T   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN
# 3004   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN  ...    NaN
#
#      Base53 Base54 Base55 Base56 Base57 Base58 Base59 Base60 class
# 0       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     N
# 1       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     N
# 2       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     N
# 3       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    IE
# 4       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     N
# ...     ...    ...    ...    ...    ...    ...    ...    ...   ...
# 3000    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     N
# 3001    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     N
# 3002    NaN      T    NaN    NaN    NaN    NaN    NaN    NaN     N
# 3003    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN     N
# 3004    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    IE
#
# [3005 rows x 61 columns]

# %%
n = len(S.columns)-1
print(f"Number of features  = {n}")
# Out:
# Number of features  = 60

# %%
print(f"Does # of features = d  = {not S.dropna().empty}")
# Out:
# Does # of features = d  = False

# %%
# Count non-NaN values for each row
non_nan_counts = S.count(axis=1)

# Find the index
max_non_nan_row_index = non_nan_counts.idxmax()

# Retrieve the row
max_non_nan_row = S.loc[max_non_nan_row_index]

# Number of non-NaN values in the row
max_non_nan_count = non_nan_counts[max_non_nan_row_index]

d = max_non_nan_count - 1

print(f"d = {d}") # remove 1 because of last class column
# Out:
# d = 5

# %%
column_values_extension = []

for column in S.columns[:-1]:  # ignoring class column
    unique_values_extension = list(S[column].dropna().unique()) + ['*']
    random.shuffle(unique_values_extension)  # Shuffling the unique values list
    column_values_extension.append(unique_values_extension)

extended_combinations_iterator = itertools.product(*column_values_extension)

extended_combinations = list(itertools.islice(extended_combinations_iterator, 100000))

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="cover")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("NC EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NC.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [1:50:54<00:00, 15.03it/s]
# NC EAR
# (Max Depth, Min Depth, Average Depth) = (52, 52, 52.0)
# Running time = 6654.828259706497

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("NCgreedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NCgreedy.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [6:36:50<00:00,  4.20it/s]
# NCgreedy EAR
# (Max Depth, Min Depth, Average Depth) = (45, 45, 45.0)
# Running time = 23810.211591959

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_G(C="EAR")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("Greedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
Gr.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [1:28:58<00:00, 18.73it/s]
# Greedy EAR
# (Max Depth, Min Depth, Average Depth) = (43, 43, 43.0)
# Running time = 5338.206468105316

# %% [markdown]
# # Mushroom

# %%
# Libraries
import itertools
from importlib import resources
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo
import random
import time

from drdt.helper_functions import DecisionRuleCreatorFromDecisionTable, Reduction, R_SR, R_AD, SAlphaStep, SPlus, SMax, NCover, NGreedy
from drdt.algorithms import DynamicProgrammingAlgorithms, A_C_N, A_C_G
from drdt.helper_functions import DecisionRuleCreatorFromDecisionTable
pd.options.mode.chained_assignment = None

# %%
problems = ['AR', 'EAR', 'SR', 'ESR', 'AD', 'EAD']
dataset_name = "Mushroom"

DP = []
NC = []
NCgreedy = []
Gr = []

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_mushroom') as dataset_path:
    S = pd.read_csv(dataset_path).applymap(lambda x: str(x) if pd.notnull(x) else x)
S = S.dropna(axis=1, how='all') # Drop the columns with all None
S
# Out:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_67526/819983034.py:1: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('datasets.DecisionRuleSystems', 'DRS_mushroom') as dataset_path:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_67526/819983034.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   S = pd.read_csv(dataset_path).applymap(lambda x: str(x) if pd.notnull(x) else x)
#      cap-shape cap-surface cap-color bruises odor gill-spacing gill-size  \
# 0          NaN         NaN       NaN     NaN    p          NaN       NaN
# 1          NaN         NaN       NaN     NaN    a          NaN       NaN
# 2          NaN         NaN       NaN     NaN    l          NaN       NaN
# 3          NaN         NaN       NaN     NaN    p          NaN       NaN
# 4          NaN         NaN       NaN     NaN  NaN          NaN       NaN
# ...        ...         ...       ...     ...  ...          ...       ...
# 8119       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8120       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8121         f         NaN       NaN     NaN  NaN          NaN       NaN
# 8122         k         NaN       NaN     NaN  NaN          NaN       NaN
# 8123       NaN         NaN       NaN       f  NaN          NaN       NaN
#
#      gill-color stalk-shape stalk-root stalk-surface-above-ring  \
# 0           NaN         NaN        NaN                      NaN
# 1           NaN         NaN        NaN                      NaN
# 2           NaN         NaN        NaN                      NaN
# 3           NaN         NaN        NaN                      NaN
# 4           NaN         NaN        NaN                      NaN
# ...         ...         ...        ...                      ...
# 8119        NaN         NaN        NaN                      NaN
# 8120        NaN         NaN        NaN                      NaN
# 8121        NaN         NaN        NaN                      NaN
# 8122        NaN         NaN        NaN                      NaN
# 8123        NaN         NaN        NaN                      NaN
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                         NaN                    NaN                    NaN
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 8119                      NaN                    NaN                    NaN
# 8120                      NaN                    NaN                    NaN
# 8121                      NaN                    NaN                    NaN
# 8122                      NaN                    NaN                    NaN
# 8123                      NaN                    NaN                    NaN
#
#      ring-number ring-type spore-print-color population habitat class
# 0            NaN       NaN               NaN        NaN     NaN     p
# 1            NaN       NaN               NaN        NaN     NaN     e
# 2            NaN       NaN               NaN        NaN     NaN     e
# 3            NaN       NaN               NaN        NaN     NaN     p
# 4            NaN       NaN               NaN          a     NaN     e
# ...          ...       ...               ...        ...     ...   ...
# 8119         NaN       NaN               NaN        NaN     NaN     e
# 8120         NaN       NaN               NaN        NaN     NaN     e
# 8121         NaN       NaN               NaN        NaN     NaN     e
# 8122         NaN       NaN               NaN        NaN     NaN     p
# 8123         NaN       NaN               NaN        NaN     NaN     e
#
# [8124 rows x 20 columns]

# %%
n = len(S.columns)-1
print(f"Number of features  = {n}")
# Out:
# Number of features  = 19

# %%
print(f"Does # of features = d  = {not S.dropna().empty}")
# Out:
# Does # of features = d  = False

# %%
# Count non-NaN values for each row
non_nan_counts = S.count(axis=1)

# Find the index
max_non_nan_row_index = non_nan_counts.idxmax()

# Retrieve the row
max_non_nan_row = S.loc[max_non_nan_row_index]

# Number of non-NaN values in the row
max_non_nan_count = non_nan_counts[max_non_nan_row_index]

d = max_non_nan_count - 1

print(f"d = {d}") # remove 1 because of last class column
# Out:
# d = 2

# %%
column_values_extension = []

for column in S.columns[:-1]:  # ignoring class column
    unique_values_extension = list(S[column].dropna().unique()) + ['*']
    random.shuffle(unique_values_extension)  # Shuffling the unique values list
    column_values_extension.append(unique_values_extension)

extended_combinations_iterator = itertools.product(*column_values_extension)

extended_combinations = list(itertools.islice(extended_combinations_iterator, 100000))

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="cover")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("NC EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NC.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|████████████████████████████████| 100000/100000 [11:04:38<00:00,  2.51it/s]
# NC EAR
# (Max Depth, Min Depth, Average Depth) = (17, 17, 17.0)
# Running time = 39878.3538479805

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("NCgreedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NCgreedy.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [1:31:06<00:00, 18.29it/s]
# NCgreedy EAR
# (Max Depth, Min Depth, Average Depth) = (17, 17, 17.0)
# Running time = 5466.658835887909

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_G(C="EAR")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("Greedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
Gr.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [1:05:21<00:00, 25.50it/s]
# Greedy EAR
# (Max Depth, Min Depth, Average Depth) = (17, 17, 17.0)
# Running time = 3921.2181208133698

# %% [markdown]
# # Soybean

# %%
# Libraries
import itertools
from importlib import resources
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from ucimlrepo import fetch_ucirepo
import random
import time

from drdt.helper_functions import DecisionRuleCreatorFromDecisionTable, Reduction, R_SR, R_AD, SAlphaStep, SPlus, SMax, NCover, NGreedy
from drdt.algorithms import DynamicProgrammingAlgorithms, A_C_N, A_C_G
from drdt.helper_functions import DecisionRuleCreatorFromDecisionTable
pd.options.mode.chained_assignment = None

# %%
problems = ['AR', 'EAR', 'SR', 'ESR', 'AD', 'EAD']
dataset_name = "Soybean"

DP = []
NC = []
NCgreedy = []
Gr = []

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_soybean') as dataset_path:
    S = pd.read_csv(dataset_path).applymap(lambda x: str(x) if pd.notnull(x) else x)
S = S.dropna(axis=1, how='all') # Drop the columns with all None
S
# Out:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_67526/113577302.py:1: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('datasets.DecisionRuleSystems', 'DRS_soybean') as dataset_path:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_67526/113577302.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   S = pd.read_csv(dataset_path).applymap(lambda x: str(x) if pd.notnull(x) else x)
#     date plant-stand precip temp hail crop-hist area-damaged severity  \
# 0    0.0         0.0    NaN  NaN  NaN       NaN          NaN      NaN
# 1    0.0         NaN    NaN  NaN  NaN       NaN          NaN      NaN
# 2    NaN         NaN    1.0  NaN  NaN       NaN          NaN      NaN
# 3    0.0         NaN    NaN  NaN  NaN       NaN          2.0      NaN
# 4    0.0         NaN    NaN  NaN  NaN       NaN          NaN      NaN
# ..   ...         ...    ...  ...  ...       ...          ...      ...
# 298  NaN         NaN    NaN  NaN  NaN       3.0          NaN      NaN
# 299  NaN         NaN    NaN  NaN  NaN       3.0          NaN      NaN
# 300  NaN         NaN    NaN  NaN  NaN       3.0          NaN      NaN
# 301  NaN         NaN    NaN  NaN  1.0       NaN          NaN      NaN
# 302  NaN         NaN    NaN  NaN  1.0       NaN          NaN      NaN
#
#     seed-tmt germination  ... external-decay mycelium int-discolor fruit-pods  \
# 0        NaN         NaN  ...            NaN      NaN          NaN        NaN
# 1        NaN         0.0  ...            NaN      NaN          NaN        NaN
# 2        NaN         NaN  ...            NaN      NaN          NaN        NaN
# 3        NaN         NaN  ...            NaN      NaN          NaN        NaN
# 4        NaN         NaN  ...            NaN      NaN          NaN        NaN
# ..       ...         ...  ...            ...      ...          ...        ...
# 298      NaN         NaN  ...            NaN      NaN          NaN        NaN
# 299      NaN         NaN  ...            NaN      NaN          NaN        NaN
# 300      NaN         NaN  ...            NaN      NaN          NaN        NaN
# 301      NaN         NaN  ...            NaN      NaN          NaN        NaN
# 302      NaN         NaN  ...            NaN      NaN          NaN        NaN
#
#     fruit-spots seed-discolor seed-size shriveling roots                 class
# 0           NaN           NaN       NaN        NaN   NaN           anthracnose
# 1           NaN           NaN       NaN        NaN   NaN      phytophthora-rot
# 2           NaN           NaN       NaN        NaN   NaN      phytophthora-rot
# 3           NaN           NaN       NaN        NaN   NaN            brown-spot
# 4           NaN           NaN       NaN        NaN   NaN  rhizoctonia-root-rot
# ..          ...           ...       ...        ...   ...                   ...
# 298         1.0           NaN       NaN        NaN   NaN    frog-eye-leaf-spot
# 299         1.0           NaN       NaN        NaN   NaN    frog-eye-leaf-spot
# 300         1.0           NaN       NaN        NaN   NaN    frog-eye-leaf-spot
# 301         2.0           NaN       NaN        NaN   NaN           anthracnose
# 302         2.0           NaN       NaN        NaN   NaN           anthracnose
#
# [303 rows x 33 columns]

# %%
n = len(S.columns)-1
print(f"Number of features  = {n}")
# Out:
# Number of features  = 32

# %%
print(f"Does # of afeatures = d  = {not S.dropna().empty}")
# Out:
# Does # of afeatures = d  = False

# %%
# Count non-NaN values for each row
non_nan_counts = S.count(axis=1)

# Find the index
max_non_nan_row_index = non_nan_counts.idxmax()

# Retrieve the row
max_non_nan_row = S.loc[max_non_nan_row_index]

# Number of non-NaN values in the row
max_non_nan_count = non_nan_counts[max_non_nan_row_index]

d = max_non_nan_count - 1

print(f"d = {d}") # remove 1 because of last class column
# Out:
# d = 5

# %%
column_values_extension = []

for column in S.columns[:-1]:  # ignoring class column
    unique_values_extension = list(S[column].dropna().unique()) + ['*']
    random.shuffle(unique_values_extension)  # Shuffling the unique values list
    column_values_extension.append(unique_values_extension)

extended_combinations_iterator = itertools.product(*column_values_extension)

extended_combinations = list(itertools.islice(extended_combinations_iterator, 100000))

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="cover")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("NC EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NC.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [1:18:46<00:00, 21.16it/s]
# NC EAR
# (Max Depth, Min Depth, Average Depth) = (32, 29, 29.78816)
# Running time = 4726.805176019669

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("NCgreedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NCgreedy.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|█████████████████████████████████| 100000/100000 [1:44:31<00:00, 15.94it/s]
# NCgreedy EAR
# (Max Depth, Min Depth, Average Depth) = (28, 24, 25.46832)
# Running time = 6271.786036014557

# %%
start_time = time.time()

depths = []

for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]
    
    alg = A_C_G(C="EAR")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
    
end_time = time.time()
    
print("Greedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
Gr.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|███████████████████████████████████| 100000/100000 [23:09<00:00, 71.96it/s]
# Greedy EAR
# (Max Depth, Min Depth, Average Depth) = (27, 22, 24.46832)
# Running time = 1389.5830481052399
