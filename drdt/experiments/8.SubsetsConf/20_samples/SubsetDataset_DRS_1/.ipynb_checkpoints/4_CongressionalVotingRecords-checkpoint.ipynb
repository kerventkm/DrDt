# %%
# Libraries
import itertools
from importlib import resources
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
import time

from drdt.helper_functions import DecisionRuleCreatorFromDecisionTable, Reduction, R_SR, R_AD, SAlphaStep, SPlus, SMax, NCover, NGreedy
from drdt.algorithms import DynamicProgrammingAlgorithms, A_C_N, A_C_G

# %%
problems = ['AR', 'EAR', 'SR', 'ESR', 'AD', 'EAD']
dataset_name = "Breast Cancer"

DP = []
NC = []
NCgreedy = []
Gr = []

# %% [markdown]
# # Loading Data

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_congressional_voting_records') as dataset_path:
    S = pd.read_csv(dataset_path).sample(n=20, random_state=42).applymap(lambda x: str(x) if pd.notnull(x) else x)
S = S.dropna(axis=1, how='all') # Drop the columns with all None
S
# Out:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_34981/614007556.py:1: DeprecationWarning: path is deprecated. Use files() instead. Refer to https://importlib-resources.readthedocs.io/en/latest/using.html#migrating-from-legacy for migration advice.
#   with resources.path('datasets.DecisionRuleSystems', 'DRS_congressional_voting_records') as dataset_path:
# /var/folders/06/0m2hb6f927s6rdyhxjrbss740r2h_1/T/ipykernel_34981/614007556.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   S = pd.read_csv(dataset_path).sample(n=20, random_state=42).applymap(lambda x: str(x) if pd.notnull(x) else x)
#     handicapped-infants water-project-cost-sharing  \
# 30                  NaN                          n
# 126                 NaN                        NaN
# 199                 NaN                        NaN
# 142                 NaN                        NaN
# 254                 NaN                        NaN
# 237                 NaN                        NaN
# 97                  NaN                        NaN
# 206                 NaN                          n
# 258                 NaN                        NaN
# 144                 NaN                        NaN
# 79                    n                        NaN
# 209                 NaN                          n
# 231                 NaN                        NaN
# 101                   n                        NaN
# 195                 NaN                        NaN
# 114                 NaN                        NaN
# 194                 NaN                        NaN
# 60                  NaN                          n
# 203                 NaN                        NaN
# 242                 NaN                        NaN
#
#     adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 30                                  n                    y             NaN
# 126                               NaN                    n             NaN
# 199                               NaN                    n             NaN
# 142                               NaN                    n             NaN
# 254                               NaN                    n             NaN
# 237                               NaN                    n             NaN
# 97                                  n                    y             NaN
# 206                               NaN                    y             NaN
# 258                               NaN                    n             NaN
# 144                               NaN                    n             NaN
# 79                                NaN                  NaN             NaN
# 209                               NaN                    y             NaN
# 231                               NaN                    n             NaN
# 101                               NaN                    y             NaN
# 195                               NaN                    n             NaN
# 114                               NaN                    n             NaN
# 194                               NaN                    n             NaN
# 60                                NaN                    y               n
# 203                               NaN                    n             NaN
# 242                               NaN                    n             NaN
#
#     anti-satellite-test-ban aid-to-nicaraguan-contras mx-missile  \
# 30                      NaN                       NaN        NaN
# 126                     NaN                       NaN        NaN
# 199                     NaN                       NaN        NaN
# 142                     NaN                         n        NaN
# 254                     NaN                       NaN        NaN
# 237                     NaN                       NaN        NaN
# 97                      NaN                       NaN        NaN
# 206                     NaN                       NaN        NaN
# 258                     NaN                       NaN        NaN
# 144                     NaN                       NaN          n
# 79                      NaN                       NaN        NaN
# 209                     NaN                       NaN        NaN
# 231                     NaN                       NaN        NaN
# 101                       y                       NaN        NaN
# 195                     NaN                       NaN        NaN
# 114                     NaN                       NaN        NaN
# 194                     NaN                       NaN        NaN
# 60                      NaN                       NaN        NaN
# 203                     NaN                       NaN        NaN
# 242                     NaN                       NaN        NaN
#
#     synfuels-corporation-cutback crime export-administration-act-south-africa  \
# 30                           NaN   NaN                                    NaN
# 126                          NaN     n                                    NaN
# 199                          NaN   NaN                                    NaN
# 142                          NaN   NaN                                    NaN
# 254                          NaN   NaN                                    NaN
# 237                          NaN   NaN                                    NaN
# 97                             n   NaN                                    NaN
# 206                          NaN   NaN                                    NaN
# 258                          NaN   NaN                                    NaN
# 144                          NaN   NaN                                    NaN
# 79                             n   NaN                                      n
# 209                          NaN   NaN                                    NaN
# 231                          NaN   NaN                                    NaN
# 101                          NaN   NaN                                    NaN
# 195                          NaN   NaN                                    NaN
# 114                            y   NaN                                    NaN
# 194                          NaN   NaN                                    NaN
# 60                           NaN   NaN                                    NaN
# 203                          NaN   NaN                                    NaN
# 242                          NaN   NaN                                    NaN
#
#           class
# 30   republican
# 126    democrat
# 199    democrat
# 142    democrat
# 254    democrat
# 237    democrat
# 97   republican
# 206  republican
# 258    democrat
# 144    democrat
# 79   republican
# 209  republican
# 231    democrat
# 101  republican
# 195    democrat
# 114    democrat
# 194    democrat
# 60   republican
# 203    democrat
# 242    democrat

# %% [markdown]
# # Dataset Analyses

# %%
n = len(S.columns)-1
print(f"Number of features  = {n}")
# Out:
# Number of features  = 11

# %%
print(f"Does # of features = d  = {not S.dropna().empty}")
# Out:
# Does # of features = d  = False

# %%
# Count non-NaN values for each row
non_nan_counts = S.count(axis=1)

# Find the index
max_non_nan_row_index = non_nan_counts.idxmax()

# Retrieve the row
max_non_nan_row = S.loc[max_non_nan_row_index]

# Number of non-NaN values in the row
max_non_nan_count = non_nan_counts[max_non_nan_row_index]

d = max_non_nan_count - 1

print(f"d = {d}") # remove 1 because of last class column
# Out:
# d = 3

# %% [markdown]
# # Dynamic Programming

# %%
start_time = time.time()
alg = DynamicProgrammingAlgorithms(C="EAR")
depth = alg.A_DP(S)
end_time = time.time()

print(f"DP EAR = {depth}")
print("Running time =", end_time - start_time)
# Out:
# DP EAR = 8
# Running time = 4668.85764503479

# %% [markdown]
# # Combinations

# %%
column_values_extension = []

for column in S.columns[:-1]: #ignoring class column
    column_values_extension.append(list(S[column].dropna().unique()) + ['*'])
    
# All possible combinations with extension    
extended_combinations = list(itertools.product(*column_values_extension))

print('Number of Possible combinations =', len(extended_combinations))
# Out:
# Number of Possible combinations = 4608

# %% [markdown]
# # Node Cover

# %%
depths = []

start_time = time.time()
for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]

    alg = A_C_N(C="EAR", N="cover")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
end_time = time.time()

print("NC EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NC.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|██████████████████████████████████████| 4608/4608 [00:15<00:00, 294.48it/s]
# NC EAR
# (Max Depth, Min Depth, Average Depth) = (9, 6, 7.333333333333333)
# Running time = 15.66927194595337

# %% [markdown]
# # Node Cover Greedy

# %%
depths = []

start_time = time.time()
for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]

    alg = A_C_N(C="EAR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
end_time = time.time()

print("NCgreedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
NCgreedy.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|██████████████████████████████████████| 4608/4608 [00:26<00:00, 172.95it/s]
# NCgreedy EAR
# (Max Depth, Min Depth, Average Depth) = (8, 2, 4.861111111111111)
# Running time = 26.644715070724487

# %% [markdown]
# # Greedy

# %%
depths = []


start_time = time.time()
for comb in tqdm(extended_combinations):
    #creating delta
    delta = pd.DataFrame([list(comb)], columns=list(S.columns[:-1]))
    
    delta = delta.loc[0]

    alg = A_C_G(C="EAR")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
end_time = time.time()

print("Greedy EAR")    
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
Gr.append((max(depths), min(depths), round(sum(depths)/len(depths), 2)))
print("Running time =", end_time - start_time)
# Out:
# 100%|██████████████████████████████████████| 4608/4608 [00:09<00:00, 482.19it/s]
# Greedy EAR
# (Max Depth, Min Depth, Average Depth) = (8, 2, 4.638888888888889)
# Running time = 9.55731987953186
