# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_G

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_tic-tac-toe') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#     top-left-square top-middle-square top-right-square middle-left-square  \
# 0               NaN               NaN              NaN                NaN
# 1               NaN               NaN              NaN                NaN
# 2               NaN               NaN              NaN                NaN
# 3               NaN               NaN                x                NaN
# 4               NaN                 x              NaN                  x
# ..              ...               ...              ...                ...
# 953               o               NaN              NaN                NaN
# 954             NaN               NaN                o                  x
# 955               o               NaN              NaN                NaN
# 956               o               NaN              NaN                NaN
# 957               o               NaN              NaN                NaN
#
#     middle-middle-square middle-right-square bottom-left-square  \
# 0                      o                   o                NaN
# 1                      o                   o                  o
# 2                      o                   o                  o
# 3                    NaN                   o                  o
# 4                    NaN                 NaN                  b
# ..                   ...                 ...                ...
# 953                  NaN                 NaN                NaN
# 954                  NaN                 NaN                NaN
# 955                  NaN                   x                NaN
# 956                  NaN                   x                NaN
# 957                  NaN                 NaN                NaN
#
#     bottom-middle-square bottom-right-square     class
# 0                      o                   o  positive
# 1                    NaN                   o  positive
# 2                      o                 NaN  positive
# 3                    NaN                   b  positive
# 4                    NaN                   b  positive
# ..                   ...                 ...       ...
# 953                    x                 NaN  negative
# 954                  NaN                 NaN  negative
# 955                  NaN                 NaN  negative
# 956                  NaN                 NaN  negative
# 957                    x                 NaN  negative
#
# [958 rows x 10 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 262144

# %%
# Possible values for each featue
top_left_square_values = ['x', 'o', 'b', '*']
top_middle_square_values = ['x', 'o', 'b', '*']
top_right_square_values = ['x', 'o', 'b', '*']
middle_left_square_values = ['x', 'o', 'b', '*']
middle_middle_square_values = ['x', 'o', 'b', '*']
middle_right_square_values = ['x', 'o', 'b', '*']
bottom_left_square_values = ['x', 'o', 'b', '*']
bottom_middle_square_values = ['x', 'o', 'b', '*']
bottom_right_square_values = ['x', 'o', 'b', '*']

# All possible combinations
combinations = list(itertools.product(top_left_square_values, 
                                      top_middle_square_values, 
                                      top_right_square_values, 
                                      middle_left_square_values, 
                                      middle_middle_square_values, 
                                      middle_right_square_values,
                                      bottom_left_square_values,
                                      bottom_middle_square_values,
                                      bottom_right_square_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8]]],
    columns=['top-left-square',
             'top-middle-square',
             'top-right-square',
             'middle-left-square', 
             'middle-middle-square', 
             'middle-right-square',
             'bottom-left-square',
             'bottom-middle-square',
             'bottom-right-square'])
    
    delta = delta.loc[0]
    
    alg = A_C_G(C="ESR")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                   | 2/262144 [01:06<2434:27:24, 33.43s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      17 delta = delta.loc[0]
#      19 alg = A_C_G(C="ESR")
# ---> 21 depth, _ = alg.solve(S, delta=delta)
#      23 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:282, in A_C_G.solve(self, S, delta)
#     279             Q = S.copy()
#     280             while True:
#     281                 # Step 1
# --> 282                 P = self.R_C(Q)
#     283                 if (P.empty or P.iloc[:, :-1].isna().all().all()):
#     284                     if P.empty:
#     285 #                             print("There is no such rule")
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:37, in R_SR(S)
#      35 if i in to_remove or j in to_remove:
#      36     continue
# ---> 37 r1, r2 = S.iloc[i][:-1], S.iloc[j][:-1] # Exclude the last column
#      38 # Check if r1 is a subset of r2
#      39 if all(pd.isna(r1[k]) or r1[k] == r2[k] for k in S.columns[:-1]):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:984, in Series.__getitem__(self, key)
#     981     key = np.asarray(key, dtype=bool)
#     982     return self._get_values(key)
# --> 984 return self._get_with(key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:992, in Series._get_with(self, key)
#     988 if isinstance(key, slice):
#     989     # _convert_slice_indexer to determine if this slice is positional
#     990     #  or label based, and if the latter, convert to positional
#     991     slobj = self.index._convert_slice_indexer(key, kind="getitem")
# --> 992     return self._slice(slobj)
#     993 elif isinstance(key, ABCDataFrame):
#     994     raise TypeError(
#     995         "Indexing a Series with DataFrame is not "
#     996         "supported, use the appropriate DataFrame column"
#     997     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:941, in Series._slice(self, slobj, axis)
#     938 def _slice(self, slobj: slice, axis: int = 0) -> Series:
#     939     # axis kwarg is retained for compat with NDFrame method
#     940     #  _slice is *always* positional
# --> 941     return self._get_values(slobj)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1044, in Series._get_values(self, indexer)
#    1042 def _get_values(self, indexer):
#    1043     try:
# -> 1044         new_mgr = self._mgr.getitem_mgr(indexer)
#    1045         return self._constructor(new_mgr).__finalize__(self)
#    1046     except ValueError:
#    1047         # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1048         #  see tests.series.timeseries.test_mpl_compat_hack
#    1049         # the asarray is needed to avoid returning a 2D DatetimeArray
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:1808, in SingleBlockManager.getitem_mgr(self, indexer)
#    1806 def getitem_mgr(self, indexer) -> SingleBlockManager:
#    1807     # similar to get_slice, but not restricted to slice indexer
# -> 1808     blk = self._block
#    1809     array = blk._slice(indexer)
#    1810     if array.ndim > 1:
#    1811         # This will be caught by Series._get_values
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
