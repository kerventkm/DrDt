# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_tic-tac-toe') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#     top-left-square top-middle-square top-right-square middle-left-square  \
# 0               NaN               NaN              NaN                NaN
# 1               NaN               NaN              NaN                NaN
# 2               NaN               NaN              NaN                NaN
# 3               NaN               NaN                x                NaN
# 4               NaN                 x              NaN                  x
# ..              ...               ...              ...                ...
# 953               o               NaN              NaN                NaN
# 954             NaN               NaN                o                  x
# 955               o               NaN              NaN                NaN
# 956               o               NaN              NaN                NaN
# 957               o               NaN              NaN                NaN
#
#     middle-middle-square middle-right-square bottom-left-square  \
# 0                      o                   o                NaN
# 1                      o                   o                  o
# 2                      o                   o                  o
# 3                    NaN                   o                  o
# 4                    NaN                 NaN                  b
# ..                   ...                 ...                ...
# 953                  NaN                 NaN                NaN
# 954                  NaN                 NaN                NaN
# 955                  NaN                   x                NaN
# 956                  NaN                   x                NaN
# 957                  NaN                 NaN                NaN
#
#     bottom-middle-square bottom-right-square     class
# 0                      o                   o  positive
# 1                    NaN                   o  positive
# 2                      o                 NaN  positive
# 3                    NaN                   b  positive
# 4                    NaN                   b  positive
# ..                   ...                 ...       ...
# 953                    x                 NaN  negative
# 954                  NaN                 NaN  negative
# 955                  NaN                 NaN  negative
# 956                  NaN                 NaN  negative
# 957                    x                 NaN  negative
#
# [958 rows x 10 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 262144

# %%
# Possible values for each featue
top_left_square_values = ['x', 'o', 'b', '*']
top_middle_square_values = ['x', 'o', 'b', '*']
top_right_square_values = ['x', 'o', 'b', '*']
middle_left_square_values = ['x', 'o', 'b', '*']
middle_middle_square_values = ['x', 'o', 'b', '*']
middle_right_square_values = ['x', 'o', 'b', '*']
bottom_left_square_values = ['x', 'o', 'b', '*']
bottom_middle_square_values = ['x', 'o', 'b', '*']
bottom_right_square_values = ['x', 'o', 'b', '*']

# All possible combinations
combinations = list(itertools.product(top_left_square_values, 
                                      top_middle_square_values, 
                                      top_right_square_values, 
                                      middle_left_square_values, 
                                      middle_middle_square_values, 
                                      middle_right_square_values,
                                      bottom_left_square_values,
                                      bottom_middle_square_values,
                                      bottom_right_square_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8]]],
    columns=['top-left-square',
             'top-middle-square',
             'top-right-square',
             'middle-left-square', 
             'middle-middle-square', 
             'middle-right-square',
             'bottom-left-square',
             'bottom-middle-square',
             'bottom-right-square'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="EAD", N="cover")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                    | 5/262144 [01:08<990:37:27, 13.60s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      17 delta = delta.loc[0]
#      19 alg = A_C_N(C="EAD", N="cover")
# ---> 21 depth, _ = alg.solve(S, delta=delta)
#      23 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:164, in A_C_N.solve(self, S, delta)
#     161                 Q = S.copy()
#     162                 while True:
#     163                     # Step 1
# --> 164                     P = self.R_C(Q)
#     165                     if (P.empty or P.iloc[:, :-1].isna().all().all()):
#     166                         if P.empty:
#     167 #                             print("There is no such rule")
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:62, in R_AD(S)
#      59     continue
#      60 r1, r2 = S.iloc[i], S.iloc[j]
# ---> 62 if all(pd.isna(r1[k]) or r1[k] == r2[k] for k in S.columns):
#      63     to_remove.add(j)
#      64 # Check if r2 is a subset of r1
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:62, in <genexpr>(.0)
#      59     continue
#      60 r1, r2 = S.iloc[i], S.iloc[j]
# ---> 62 if all(pd.isna(r1[k]) or r1[k] == r2[k] for k in S.columns):
#      63     to_remove.add(j)
#      64 # Check if r2 is a subset of r1
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3619, in Index.get_loc(self, key, method, tolerance)
#    3614 if tolerance is not None:
#    3615     raise ValueError(
#    3616         "tolerance argument only valid if using pad, "
#    3617         "backfill or nearest lookups"
#    3618     )
# -> 3619 casted_key = self._maybe_cast_indexer(key)
#    3620 try:
#    3621     return self._engine.get_loc(casted_key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6290, in Index._maybe_cast_indexer(self, key)
#    6285 """
#    6286 If we have a float key and are not a floating index, then try to cast
#    6287 to an int if equivalent.
#    6288 """
#    6289 if not self.is_floating():
# -> 6290     return com.cast_scalar_indexer(key)
#    6291 return key
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py:175, in cast_scalar_indexer(val, warn_float)
#     161 """
#     162 To avoid numpy DeprecationWarnings, cast float to integer where valid.
#     163
#    (...)
#     172 outval : scalar
#     173 """
#     174 # assumes lib.is_scalar(val)
# --> 175 if lib.is_float(val) and val.is_integer():
#     176     if warn_float:
#     177         warnings.warn(
#     178             "Indexing with a float is deprecated, and will raise an IndexError "
#     179             "in pandas 2.0. You can manually convert to an integer key instead.",
#     180             FutureWarning,
#     181             stacklevel=find_stack_level(),
#     182         )
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
