# %%
# Libraries
import matplotlib.pyplot as plt

# %%
problems = ['AR', 'EAR', 'SR', 'ESR', 'AD', 'EAD']

# %% [markdown]
# # Full Dataset

# %% [markdown]
# ### Car Evaluation

# %%
full_CE_NC = [(6,6,6), (6,6,6), (6,6,6), (6,6,6), (6,6,6), (6,6,6)]
full_CE_NCgreedy = [(6,6,6), (6,6,6), (6,3,5.57), (6,3,5.69), (6,5,5.98), (6,6,6)]
full_CE_Gr = [(6,5,5.86), (6,5,5.64), (6,3,3.68), (6,3,4.1), (6,4,5.38), (6,4,5.27)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for a,_,_ in full_CE_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in full_CE_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in full_CE_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Max of min depth in Car Evaluation Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,a,_ in full_CE_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,a,_ in full_CE_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,a,_ in full_CE_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Min of min depth in Car Evaluation Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,_,a in full_CE_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,_,a in full_CE_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,_,a in full_CE_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Average of min depth in Car Evaluation Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Tic Tac Toe

# %%
full_TTT_NC = [(9,9,9), (9,9,9), (9,5,6.43), (9,5,7.39), (9,5,8.32), (9,5,8.63)]
full_TTT_NCgreedy = [(9,8,8.99), (9,7,8.9), (9,3,5.84), (9,3,7.04), (9,5,8.31), (9,5,8.38)]
full_TTT_Gr = [(9,8,8.98), (9,7,8.79), (9,3,5.18), (9,3,6.25), (9,5,7.32), (9,5,7.7)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for a,_,_ in full_TTT_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in full_TTT_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in full_TTT_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Max of min depth in Tic Tac Toe Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,a,_ in full_TTT_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,a,_ in full_TTT_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,a,_ in full_TTT_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Min of min depth in Tic Tac Toe Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,_,a in full_TTT_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,_,a in full_TTT_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,_,a in full_TTT_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Average of min depth in Tic Tac Toe Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Balance Scale

# %%
full_BS_NC = [(4,4,4), (4,4,4), (4,4,4), (4,4,4), (4,4,4), (4,4,4)]
full_BS_NCgreedy = [(4,4,4), (4,2,3.84), (4,3,3.64), (4,2,3.63), (4,3,3.64), (4,2,3.63)]
full_BS_Gr = [(4,4,4), (4,2,3.84), (4,3,3.57), (4,2,3.59), (4,3,3.57), (4,2,3.59)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for a,_,_ in full_BS_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in full_BS_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in full_BS_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Max of min depth in Balance Scale Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,a,_ in full_BS_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,a,_ in full_BS_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,a,_ in full_BS_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Min of min depth in Balance Scale Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,_,a in full_BS_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,_,a in full_BS_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,_,a in full_BS_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Average of min depth in Balance Scale Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Congressional Voting Records

# %%
full_CVR_NC = [(16,11,14.67), (16,10,12.75), (8,4,5.75), (15,4,8.22), (14,8,9.73), (15,8,10.66)]
full_CVR_NCgreedy = [(16,10,14.07), (16,8,11.79), (15,1,6.75), (15,1,6.47), (15,8,10.56), (15,6,8.71)]
full_CVR_Gr = [(16,10,13.82), (16,7,11.04), (6,1,3.25), (15,1,3.91), (10,3,5.98), (15,3,6.3)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for a,_,_ in full_CVR_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in full_CVR_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in full_CVR_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Max of min depth in Congressional Voting Records Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,a,_ in full_CVR_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,a,_ in full_CVR_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,a,_ in full_CVR_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Min of min depth in Congressional Voting Records Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,_,a in full_CVR_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,_,a in full_CVR_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,_,a in full_CVR_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Average of min depth in Congressional Voting Records Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Breast Cancer

# %%
full_BC_NC = [(9,6,7.54), (9,6,7.42), (9,6,6.13), (9,6,6.3), (9,6,6.79), (9,6,6.87)]
full_BC_NCgreedy = [(9,4,6.68), (9,4,6.46), (9,1,3.77), (9,1,4.15), (9,3,5.53), (9,3,5.56)]
full_BC_Gr = [(9,4,6.49), (9,4,6.2), (9,1,3), (9,1,3.39), (9,2,4.81), (9,2,4.92)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for a,_,_ in full_BC_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in full_BC_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in full_BC_Gr], '*-', linewidth=1, label='Greedy')

plt.title('Max of min depth in Breast Cancer Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,a,_ in full_BC_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,a,_ in full_BC_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,a,_ in full_BC_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Min of min depth in Breast Cancer Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, [a for _,_,a in full_BC_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for _,_,a in full_BC_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for _,_,a in full_BC_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Average of min depth in Breast Cancer Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# # Subsets

# %% [markdown]
# ### Car Evaluation

# %%
CE_DP = [6, 6, 6, 6, 6, 6]
CE_NC = [(6,5,5.38), (6,5,5.28), (6,5,5.29), (6,5,5.23), (6,5,5.29), (6,5,5.23)]
CE_NCgreedy = [(6,4,4.69), (6,4,4.56), (6,2,4.5), (6,2,4.44), (6,2,4.5), (6,2,4.44)]
CE_Gr = [(5, 3, 3.42), (5,3,3.3), (5,2,3.13), (5, 2, 3.12), (5,2,3.15), (5,2,3.13)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, CE_DP, 'x-', linewidth=4, label='Dynamic Programming')
plt.plot(problems, [a for a,_,_ in CE_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in CE_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in CE_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Car Evaluation Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Tic Tac Toe

# %%
TTT_DP = [7, 7, 6, 7, 6, 7]
TTT_NC = [(8,5,6.5), (8,5,6.08), (8,5,6.04), (8,5,5.91), (8,5,6.24), (8,5,5.97)]
TTT_NCgreedy = [(7,3,4.49), (7,2,3.64), (7,3,4.49), (7,2,3.64), (7,3,4.49), (7,2,3.64)]
TTT_Gr = [(7,2,4.4), (7,2,3.52), (6,2,3.84), (7,2,3.33), (6,2,4.02), (7,2,3.39)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, TTT_DP, 'x-', linewidth=4, label='Dynamic Programming', c='r')
plt.plot(problems, [a for a,_,_ in TTT_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in TTT_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in TTT_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Tic Tac Toe Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Balance Scale

# %%
BS_DP = [4, 4, 4, 4, 4, 4]
BS_NC = [(4,4,4.0), (4,4,4.0), (4,4,4.0), (4,4,4.0), (4,4,4.0), (4,4,4.0)]
BS_NCgreedy = [(4,2,2.92), (4,2,2.66), (4,2,2.92), (4,2,2.66), (4,2,2.92), (4,2,2.66)]
BS_Gr = [(4,2,2.88), (4,2,2.63), (4,2,2.86), (4,2,2.62), (4,2,2.86), (4,2,2.62)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, BS_DP, 'x-', linewidth=4, label='Dynamic Programming', c='r')
plt.plot(problems, [a for a,_,_ in BS_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in BS_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in BS_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Balance Scale Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Congressional Voting Records

# %%
CVR_DP = [4, 4, 2, 4, 2, 4]
CVR_NC = [(6,4,5.0), (6,3,4.17), (3,3,3.0), (4,3,3.25), (3,3,3.0), (4,3,3.25)]
CVR_NCgreedy = [(5,4,4.5), (5,2,3.5), (4,2,3.0), (4,2,2.83), (4,2,3.0), (4,2,2.83)]
CVR_Gr = [(4,4,4.0), (4,1,2.83), (2,1,1.5), (4,1,1.58), (2,1,1.5), (4,1,1.58)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, CVR_DP, 'x-', linewidth=4, label='Dynamic Programming', c='r')
plt.plot(problems, [a for a,_,_ in CVR_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in CVR_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in CVR_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Congressional Voting Records Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Breast Cancer

# %%
BC_DP = [8, 8, 3, 8, 5, 8]
BC_NC = [(8,3,4.23), (8,3,3.85), (5,3,3.7), (8,3,3.68), (7,3,3.83), (8,3,3.69)]
BC_NCgreedy = [(8,3,4.23), (8,3,3.76), (8,2,3.6), (8,2,3.38), (8,2,3.6), (8,2,3.36)]
BC_Gr = [(8,2,4.03), (8,2,3.43), (5,1,2.83), (8,1,2.84), (6,1,3.0), (8,1,2.89)]

# %%
plt.figure(figsize=(10,6))

plt.plot(problems, BC_DP, 'x-', linewidth=4, label='Dynamic Programming', c='r')
plt.plot(problems, [a for a,_,_ in BC_NC], 'o-', linewidth=3, label='Node Cover', c='b')
plt.plot(problems, [a for a,_,_ in BC_NCgreedy], '+-', linewidth=2, label='Node Cover Greedy', c='orange')
plt.plot(problems, [a for a,_,_ in BC_Gr], '*-', linewidth=1, label='Greedy', c='g')

plt.title('Breast Cancer Dataset')
plt.xlabel('Problems')
plt.ylabel('Depth')
plt.legend(loc='best')
plt.grid(True)
plt.show()
