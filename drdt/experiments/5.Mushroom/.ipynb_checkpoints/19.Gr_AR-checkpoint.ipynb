# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_G

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_mushroom') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#      cap-shape cap-surface cap-color bruises odor gill-spacing gill-size  \
# 0          NaN         NaN       NaN     NaN    p          NaN       NaN
# 1          NaN         NaN       NaN     NaN    a          NaN       NaN
# 2          NaN         NaN       NaN     NaN    l          NaN       NaN
# 3          NaN         NaN       NaN     NaN    p          NaN       NaN
# 4          NaN         NaN       NaN     NaN  NaN          NaN       NaN
# ...        ...         ...       ...     ...  ...          ...       ...
# 8119       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8120       NaN         NaN       NaN     NaN    n          NaN       NaN
# 8121         f         NaN       NaN     NaN  NaN          NaN       NaN
# 8122         k         NaN       NaN     NaN  NaN          NaN       NaN
# 8123       NaN         NaN       NaN       f  NaN          NaN       NaN
#
#      gill-color stalk-shape stalk-root stalk-surface-above-ring  \
# 0           NaN         NaN        NaN                      NaN
# 1           NaN         NaN        NaN                      NaN
# 2           NaN         NaN        NaN                      NaN
# 3           NaN         NaN        NaN                      NaN
# 4           NaN         NaN        NaN                      NaN
# ...         ...         ...        ...                      ...
# 8119        NaN         NaN        NaN                      NaN
# 8120        NaN         NaN        NaN                      NaN
# 8121        NaN         NaN        NaN                      NaN
# 8122        NaN         NaN        NaN                      NaN
# 8123        NaN         NaN        NaN                      NaN
#
#      stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                         NaN                    NaN                    NaN
# 1                         NaN                    NaN                    NaN
# 2                         NaN                    NaN                    NaN
# 3                         NaN                    NaN                    NaN
# 4                         NaN                    NaN                    NaN
# ...                       ...                    ...                    ...
# 8119                      NaN                    NaN                    NaN
# 8120                      NaN                    NaN                    NaN
# 8121                      NaN                    NaN                    NaN
# 8122                      NaN                    NaN                    NaN
# 8123                      NaN                    NaN                    NaN
#
#      ring-number ring-type spore-print-color population habitat class
# 0            NaN       NaN               NaN        NaN     NaN     p
# 1            NaN       NaN               NaN        NaN     NaN     e
# 2            NaN       NaN               NaN        NaN     NaN     e
# 3            NaN       NaN               NaN        NaN     NaN     p
# 4            NaN       NaN               NaN          a     NaN     e
# ...          ...       ...               ...        ...     ...   ...
# 8119         NaN       NaN               NaN        NaN     NaN     e
# 8120         NaN       NaN               NaN        NaN     NaN     e
# 8121         NaN       NaN               NaN        NaN     NaN     e
# 8122         NaN       NaN               NaN        NaN     NaN     p
# 8123         NaN       NaN               NaN        NaN     NaN     e
#
# [8124 rows x 20 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())-1
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 1632960

# %%
# Possible values for each featue
cap_shape_values = ['s', 'f', 'b', 'x', 'c', 'k']
cap_surface_values = ['f', 'y', 'g']
cap_color_values = ['g', 'n', 'e', 'w', 'y', 'u', 'c', 'r', 'b', 'p']
bruises_values = ['f', 't'] 
odor_values = ['p', 'a', 'l', 'n', 'f', 'c', 'y', 's', 'm']
gill_spacing_values = ['w']
gill_size_values = ['b', 'n']
gill_color_values = ['k', 'n', 'p', 'u', 'e', 'r', 'o']
stalk_shape_values = ['t']
stalk_root_values = ['e']
stalk_surface_above_ring_values = ['f']
stalk_surface_below_ring_values = ['y']
stalk_color_above_ring_values = ['g', 'e', 'o', 'n']
stalk_color_below_ring_values = ['g', 'e', 'y']
ring_number_values = ["t"]
ring_type_values = ['f']
spore_print_color_values = ['n', 'k', 'r']
population_values = ['a']
habitat_values = ['w']


# All possible combinations
combinations = list(itertools.product(cap_shape_values, 
                                      cap_surface_values, 
                                      cap_color_values, 
                                      bruises_values, 
                                      odor_values, 
                                      gill_spacing_values,
                                      gill_size_values,
                                      gill_color_values,
                                      stalk_shape_values,
                                      stalk_root_values,
                                      stalk_surface_above_ring_values,
                                      stalk_surface_below_ring_values,
                                      stalk_color_above_ring_values,
                                      stalk_color_below_ring_values,
                                      ring_number_values,
                                      ring_type_values,
                                      spore_print_color_values,
                                      population_values,
                                      habitat_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8], comb[9], comb[10], comb[11], comb[12], comb[13], comb[14], comb[15], comb[16], comb[17], comb[18]]],
    columns=['cap-shape',
             'cap-surface',
             'cap-color',
             'bruises', 
             'odor', 
             'gill-spacing',
             'gill-size',
             'gill-color',
             'stalk-shape',
             'stalk-root',
             'stalk-surface-above-ring',
             'stalk-surface-below-ring',
             'stalk-color-above-ring',
             'stalk-color-below-ring',
             'ring-number',
             'ring-type',
             'spore-print-color',
             'population',
             'habitat'])
    
    delta = delta.loc[0]
    
    alg = A_C_G(C="AR")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                   | 48/1632960 [00:09<91:06:36,  4.98it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      27 delta = delta.loc[0]
#      29 alg = A_C_G(C="AR")
# ---> 31 depth, _ = alg.solve(S, delta=delta)
#      33 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:273, in A_C_G.solve(self, S, delta)
#     266                 # Step 2
#     267                 else:
#     268 #                     for column in P.columns:       # We choose an attribute ai ∈ A(P) with the minimum index i
#     269 #                         if P[column].notna().any():
#     270 #                             attr = column
#     271 #                             break
#     272                     self.depth += 1
# --> 273                     attr = P.iloc[:, :-1].count().idxmax() # Find the column name with the maximum number of non-NaN values
#     274                     alpha = (attr, delta[attr])
#     275                     Q = SAlphaStep(P, alpha)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:9878, in DataFrame.count(self, axis, level, numeric_only)
#    9875     result = notna(frame).sum(axis=axis)
#    9876 else:
#    9877     # GH13407
# -> 9878     series_counts = notna(frame).sum(axis=axis)
#    9879     counts = series_counts.values
#    9880     result = self._constructor_sliced(
#    9881         counts, index=frame._get_agg_axis(axis)
#    9882     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:364, in notna(obj)
#     287 def notna(obj):
#     288     """
#     289     Detect non-missing values for an array-like object.
#     290
#    (...)
#     362     Name: 1, dtype: bool
#     363     """
# --> 364     res = isna(obj)
#     365     if is_scalar(res):
#     366         return not res
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:143, in isna(obj)
#      66 def isna(obj):
#      67     """
#      68     Detect missing values for an array-like object.
#      69
#    (...)
#     141     Name: 1, dtype: bool
#     142     """
# --> 143     return _isna(obj)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:186, in _isna(obj, inf_as_na)
#     184     return result
#     185 elif isinstance(obj, ABCDataFrame):
# --> 186     return obj.isna()
#     187 elif isinstance(obj, list):
#     188     return _isna_array(np.asarray(obj, dtype=object), inf_as_na=inf_as_na)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5852, in DataFrame.isna(self)
#    5850 @doc(NDFrame.isna, klass=_shared_doc_kwargs["klass"])
#    5851 def isna(self) -> DataFrame:
# -> 5852     result = self._constructor(self._mgr.isna(func=isna))
#    5853     return result.__finalize__(self, method="isna")
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/base.py:145, in DataManager.isna(self, func)
#     143 @final
#     144 def isna(self: T, func) -> T:
# --> 145     return self.apply("apply", func=func)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:402, in Block.apply(self, func, **kwargs)
#     396 @final
#     397 def apply(self, func, **kwargs) -> list[Block]:
#     398     """
#     399     apply the function to my values; return a block if we are not
#     400     one
#     401     """
# --> 402     result = func(self.values, **kwargs)
#     404     return self._split_op_result(result)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:143, in isna(obj)
#      66 def isna(obj):
#      67     """
#      68     Detect missing values for an array-like object.
#      69
#    (...)
#     141     Name: 1, dtype: bool
#     142     """
# --> 143     return _isna(obj)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:172, in _isna(obj, inf_as_na)
#     170     return False
#     171 elif isinstance(obj, (np.ndarray, ABCExtensionArray)):
# --> 172     return _isna_array(obj, inf_as_na=inf_as_na)
#     173 elif isinstance(obj, ABCIndex):
#     174     # Try to use cached isna, which also short-circuits for integer dtypes
#     175     #  and avoids materializing RangeIndex._values
#     176     if not obj._can_hold_na:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:254, in _isna_array(values, inf_as_na)
#     252         result = values.isna()  # type: ignore[assignment]
#     253 elif is_string_or_object_np_dtype(values.dtype):
# --> 254     result = _isna_string_dtype(values, inf_as_na=inf_as_na)
#     255 elif needs_i8_conversion(dtype):
#     256     # this is the NaT pattern
#     257     result = values.view("i8") == iNaT
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/missing.py:278, in _isna_string_dtype(values, inf_as_na)
#     276     result = libmissing.isnaobj(values, inf_as_na=inf_as_na)
#     277 elif values.ndim == 2:
# --> 278     result = libmissing.isnaobj2d(values, inf_as_na=inf_as_na)
#     279 else:
#     280     # 0-D, reached via e.g. mask_missing
#     281     result = libmissing.isnaobj(values.ravel(), inf_as_na=inf_as_na)
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
