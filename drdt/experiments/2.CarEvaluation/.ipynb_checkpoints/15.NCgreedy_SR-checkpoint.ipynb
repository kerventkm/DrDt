# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_car_evaluation') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#      buying maint  doors persons lug_boot safety  class
# 0       NaN   NaN    NaN       2      NaN    NaN  unacc
# 1       NaN   NaN    NaN       2      NaN    NaN  unacc
# 2       NaN   NaN    NaN       2      NaN    NaN  unacc
# 3       NaN   NaN    NaN       2      NaN    NaN  unacc
# 4       NaN   NaN    NaN       2      NaN    NaN  unacc
# ...     ...   ...    ...     ...      ...    ...    ...
# 1723    low   NaN  5more     NaN      NaN    med   good
# 1724    low   NaN    NaN     NaN      NaN   high  vgood
# 1725    NaN   NaN    NaN     NaN      NaN    low  unacc
# 1726    low   NaN  5more     NaN      NaN    med   good
# 1727    low   NaN    NaN     NaN      big    NaN  vgood
#
# [1728 rows x 7 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())-1
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 1728

# %%
# Possible values for each featue
buying_values = ['vhigh','high','med','low']
maint_values = ['vhigh','high','med','low']
doors_values = [2,3,4,'5more']
persons_values = [2,4,'more'] 
lug_boot_values = ['small', 'med', 'big']
safety_values = ['high','med','low']

# All possible combinations
combinations = list(itertools.product(buying_values, maint_values, doors_values, persons_values, lug_boot_values, safety_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5]]],
    columns=['buying','maint','doors','persons', 'lug_boot', 'safety'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="SR", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   1%|▍                                      | 21/1728 [02:10<2:56:36,  6.21s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       9 delta = delta.loc[0]
#      11 alg = A_C_N(C="SR", N="greedy")
# ---> 13 depth, _ = alg.solve(S, delta=delta)
#      15 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:131, in A_C_N.solve(self, S, delta)
#     128                 Q = S.copy()
#     129                 while True:
#     130                     # Step 1
# --> 131                     P = self.R_C(Q)
#     132                     if (P.empty or P.iloc[:, :-1].isna().all().all()):
#     133                         if P.empty:
#     134 #                             print("There is no such rule")
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:39, in R_SR(S)
#      37 r1, r2 = S.iloc[i][:-1], S.iloc[j][:-1] # Exclude the last column
#      38 # Check if r1 is a subset of r2
# ---> 39 if all(pd.isna(r1[k]) or r1[k] == r2[k] for k in S.columns[:-1]):
#      40     to_remove.add(j)
#      41 # Check if r2 is a subset of r1
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:39, in <genexpr>(.0)
#      37 r1, r2 = S.iloc[i][:-1], S.iloc[j][:-1] # Exclude the last column
#      38 # Check if r1 is a subset of r2
# ---> 39 if all(pd.isna(r1[k]) or r1[k] == r2[k] for k in S.columns[:-1]):
#      40     to_remove.add(j)
#      41 # Check if r2 is a subset of r1
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3619, in Index.get_loc(self, key, method, tolerance)
#    3614 if tolerance is not None:
#    3615     raise ValueError(
#    3616         "tolerance argument only valid if using pad, "
#    3617         "backfill or nearest lookups"
#    3618     )
# -> 3619 casted_key = self._maybe_cast_indexer(key)
#    3620 try:
#    3621     return self._engine.get_loc(casted_key)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6289, in Index._maybe_cast_indexer(self, key)
#    6284 def _maybe_cast_indexer(self, key):
#    6285     """
#    6286     If we have a float key and are not a floating index, then try to cast
#    6287     to an int if equivalent.
#    6288     """
# -> 6289     if not self.is_floating():
#    6290         return com.cast_scalar_indexer(key)
#    6291     return key
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:2344, in Index.is_floating(self)
#    2310     """
#    2311     Check if the Index only consists of integers.
#    2312
#    (...)
#    2340     False
#    2341     """
#    2342     return self.inferred_type in ["integer"]
# -> 2344 @final
#    2345 def is_floating(self) -> bool:
#    2346     """
#    2347     Check if the Index is a floating type.
#    2348
#    (...)
#    2384     False
#    2385     """
#    2386     return self.inferred_type in ["floating", "mixed-integer-float", "integer-na"]
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
