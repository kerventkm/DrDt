# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
problems = ['AR', 'EAR', 'SR', 'ESR', 'AD', 'EAD']

# %% [markdown]
# # Congressional Voting Records

# %%
dataset_name = "Congressional Voting Records"

num_comb = [2048, 5668704,2048, 566870,2048, 566870]

n = 16

NC = [(16, 11, 14.671875,  59.4702889919281),(16, 10, 12.746227709190672, 154604.23976492882),(8, 4, 5.75, 1203.6235179901123),(15, 4, 8.221362922715967, 340705.36858296394),(14, 8, 9.734375, 765.1843540668488),(15, 8, 10.662830984176265, 228871.49410772324)]
NCgreedy = [(16, 10, 14.07421875, 146.78962683677673),(16, 8, 11.793476604176192, 445531.56550717354),(15, 1, 6.75, 1414.8079369068146),(15, 1, 6.468084393247129, 480630.32415890694),(15, 8, 10.5625, 1008.7150931358337),(15, 6, 8.719560040220863, 346070.7495121956)]
Gr = [(16, 10, 13.82421875, 58.379093408584595),(16, 7, 11.03802773967383, 125528.30564928055),(6, 1, 3.25, 1562.8323225975037),(15, 1, 3.906849895037663, 422793.6170179844),(10, 3, 5.9765625, 753.1496014595032),(15, 3, 6.296865242471819, 204708.10258078575)]

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for a,_,_,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for a,_,_,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for a,_,_,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Max of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for _,_,a,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for _,_,a,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for _,_,a,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, np.array([a for _,_,_,a in Gr])/np.array(num_comb), color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, np.array([a for _,_,_,a in NCgreedy])/np.array(num_comb), color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, np.array([a for _,_,_,a in NC])/np.array(num_comb), color='b', linewidth=15, label='Node Cover')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average Time for one sample {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Time', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Tic Tac Toe

# %%
dataset_name = "Tic Tac Toe"

num_comb = [19683, 262144,19683, 26214,19683, 26214]

n = 9

NC = [(9, 9, 9.0, 479.7350950241089),(9, 9, 9.0, 6796.248888015747),(9, 5, 6.43057460752934, 481678.2800257206),(9, 5, 7.376020447089342, 623667.7657287121),(9, 5, 8.324340801707057, 273656.8166208267),(9, 5, 8.633821622034027, 356994.98073506355)]
NCgreedy = [(9, 8, 8.992684042066758, 1190.5736050605774),(9, 7, 8.899673461914062, 14517.060420751572),(9, 3, 5.837524767565919, 552277.1119451523),(9, 3, 7.043984130617227, 676317.8958468437),(9, 5, 8.311233043743332, 368620.51747989655),(9, 5, 8.382085908293279, 461981.38072681427)]
Gr = [(9, 8, 8.983539094650206, 398.5726668834686),(9, 7, 8.788375854492188, 5054.054090499878),(9, 3, 5.183508611492151, 623989.4459254742),(9, 3, 6.24868390936141, 813357.477221489),(9, 5, 7.318853833257125, 267368.6403682232),(9, 5, 7.699740596627756, 350336.8481040001)]

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for a,_,_,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for a,_,_,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for a,_,_,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Max of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for _,_,a,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for _,_,a,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for _,_,a,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, np.array([a for _,_,_,a in Gr])/np.array(num_comb), color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, np.array([a for _,_,_,a in NCgreedy])/np.array(num_comb), color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, np.array([a for _,_,_,a in NC])/np.array(num_comb), color='b', linewidth=15, label='Node Cover')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average Time for one sample {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Time', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Breast Cancer

# %%
dataset_name = "Breast Cancer"

num_comb = [166320, 1741824,166320, 174182,166320, 174182]

n = 9

NC = [(9, 6, 7.5439634439634435, 1261.592392206192),(9, 6, 7.418340773809524, 21634.09834909439),(9, 6, 6.131132756132756, 397159.6361143589),(9, 6, 6.299927661870917, 408534.5466723442),(9, 6, 6.786568061568062, 234246.23167300224),(9, 6, 6.872593034871571, 246812.3109858036)]
NCgreedy = [(9, 4, 6.680856180856181, 6757.523385047913),(9, 4, 6.463882688492063, 63541.37019300461),(9, 1, 3.7736892736892735, 517667.174448967),(9, 1, 4.143338576890838, 537950.9294230938),(9, 3, 5.531637806637806, 333659.65543293953),(9, 3, 5.566878322673984, 343349.6230080128)]
Gr = [(9, 4, 6.488552188552188, 2201.148190498352),(9, 4, 6.20148189484127, 22021.02495288849),(9, 1, 3.0085257335257336, 602214.6119089127),(9, 1, 3.3885131643912687, 634945.0618085861),(9, 2, 4.810497835497835, 254357.80371809006),(9, 2, 4.9242631270739805, 271308.7823083401)]

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for a,_,_,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for a,_,_,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for a,_,_,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Max of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for _,_,a,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for _,_,a,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for _,_,a,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, np.array([a for _,_,_,a in Gr])/np.array(num_comb), color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, np.array([a for _,_,_,a in NCgreedy])/np.array(num_comb), color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, np.array([a for _,_,_,a in NC])/np.array(num_comb), color='b', linewidth=15, label='Node Cover')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average Time for one sample {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Time', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Car Evaluation

# %%
dataset_name = "Car Evaluation"

num_comb = [1728, 8000,1728, 8000,1728, 8000]

n = 6

NC = [(6, 6, 6.0, 13.280478954315186),(6, 6, 6.0, 60.847119092941284),(6, 6, 6.0, 11600.639131784439),(6, 6, 6.0, 43947.38357806206),(6, 6, 6.0, 7914.867172718048),(6, 6, 6.0, 26907.7487449646)]
NCgreedy = [(6, 6, 6.0, 99.89761900901794),(6, 6, 6.0, 441.61305499076843),(6, 2, 4.388888888888889, 22539.99622297287),(6, 2, 4.8615, 68939.39251303673),(6, 5, 5.815972222222222, 14975.211396217346),(6, 5, 5.8615, 47069.03486394882)]
Gr = [(6, 5, 5.995949074074074, 26.534884929656982),(6, 5, 5.85725, 115.52608895301819),(6, 2, 3.4375, 13180.988385438919),(6, 2, 4.003125, 61512.21674346924),(6, 4, 5.567708333333333, 5770.649239063263),(6, 4, 5.5415, 26379.104245901108)]

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for a,_,_,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for a,_,_,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for a,_,_,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Max of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for _,_,a,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for _,_,a,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for _,_,a,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, np.array([a for _,_,_,a in Gr])/np.array(num_comb), color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, np.array([a for _,_,_,a in NCgreedy])/np.array(num_comb), color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, np.array([a for _,_,_,a in NC])/np.array(num_comb), color='b', linewidth=15, label='Node Cover')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average Time for one sample {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Time', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# # Balance Scale

# %%
dataset_name = "Balance Scale"

num_comb = [625, 1296,625, 1296,625, 1296]

n = 4

NC = [(4, 4, 4.0, 9.604533672332764),(4, 4, 4.0, 19.507722854614258),(4, 4, 4.0, 8420.33966422081),(4, 4, 4.0, 15003.056823730469),(4, 4, 4.0, 4875.707507133484),(4, 4, 4.0, 9504.838374853134)]
NCgreedy = [(4, 4, 4.0, 25.52311897277832),(4, 2, 3.8425925925925926, 44.97996997833252),(4, 3, 3.64, 16271.680942058563),(4, 2, 3.634259259259259, 27580.649779081345),(4, 3, 3.64, 9598.64073085785),(4, 2, 3.634259259259259, 18430.10006904602)]
Gr = [(4, 4, 4.0, 5.603148460388184),(4, 2, 3.8425925925925926, 10.773743629455566),(4, 3, 3.568, 8733.566457033157),(4, 2, 3.5925925925925926, 18315.2239484787),(4, 3, 3.568, 3708.031126499176),(4, 2, 3.5925925925925926, 7534.389839172363)]

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for a,_,_,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for a,_,_,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for a,_,_,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Max of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, [a for _,_,a,_ in Gr], color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, [a for _,_,a,_ in NCgreedy], color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, [a for _,_,a,_ in NC], color='b', linewidth=15, label='Node Cover')

plt.axhline(y=n, color='r', linestyle='--', linewidth=2, label=f'n={n}')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average of min depth {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Depth', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()

# %%
problem_indices = np.arange(len(problems))

plt.figure(figsize=(15,10))

offset = 0.1
x_offsets = np.array([-1.5*offset, -0.5*offset, 0.5*offset])

plt.vlines(problem_indices + x_offsets[0], 0, np.array([a for _,_,_,a in Gr])/np.array(num_comb), color='g', linewidth=15, label='Greedy')
plt.vlines(problem_indices + x_offsets[1], 0, np.array([a for _,_,_,a in NCgreedy])/np.array(num_comb), color='orange', linewidth=15, label='Node Cover Greedy')
plt.vlines(problem_indices + x_offsets[2], 0, np.array([a for _,_,_,a in NC])/np.array(num_comb), color='b', linewidth=15, label='Node Cover')

plt.xticks(problem_indices, problems, rotation=45, ha='right')

plt.title(f'Average Time for one sample {dataset_name}', fontsize=14)
plt.xlabel('Problems', fontsize=14)
plt.ylabel('Time', fontsize=14)
plt.legend(loc='best', fontsize=14)
plt.grid(True)
plt.show()
