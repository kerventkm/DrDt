# %%
import itertools
import pandas as pd
from importlib import resources
from tqdm import tqdm

from drdt.algorithms import A_C_N

# %%
with resources.path('datasets.DecisionRuleSystems', 'DRS_breast_cancer') as dataset_path:
    S = pd.read_csv(dataset_path)   
S
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    20-29       NaN        NaN       NaN       NaN        NaN    NaN
# 1    30-39      lt40        NaN       NaN       NaN        NaN    NaN
# 2      NaN       NaN        0-4       NaN       NaN        NaN    NaN
# 3    30-39       NaN     14-Oct       NaN       NaN        NaN    NaN
# 4    30-39       NaN     14-Oct       NaN       NaN        NaN    NaN
# ..     ...       ...        ...       ...       ...        ...    ...
# 261  70-79       NaN     14-Oct       NaN       NaN        NaN    NaN
# 262  70-79       NaN        NaN    11-Sep       NaN        NaN    NaN
# 263  70-79       NaN      20-24       NaN       NaN        NaN    NaN
# 264  70-79       NaN      40-44       NaN       NaN        NaN    NaN
# 265  70-79       NaN      40-44       NaN       NaN        NaN    NaN
#
#     breast-quad irradiat                 class
# 0           NaN      NaN  no-recurrence-events
# 1           NaN      NaN  no-recurrence-events
# 2           NaN      NaN  no-recurrence-events
# 3           NaN      NaN  no-recurrence-events
# 4           NaN      NaN  no-recurrence-events
# ..          ...      ...                   ...
# 261         NaN      NaN  no-recurrence-events
# 262         NaN      NaN     recurrence-events
# 263         NaN      NaN  no-recurrence-events
# 264         NaN      NaN  no-recurrence-events
# 265         NaN      NaN  no-recurrence-events
#
# [266 rows x 10 columns]

# %%
res = 1

for col in S.columns[:-1]:
    res *= len(S[col].unique())-1
    
print("number of possible combinations =", res)
# Out:
# number of possible combinations = 166320

# %%
# Possible values for each featue
age_values = ['30-39', '40-49', '60-69', '50-59', '70-79', '20-29']
menopause_values = ['premeno', 'ge40', 'lt40']
tumor_size_values = ['30-34', '20-24', '15-19', '0-4', '25-29', '50-54', '14-Oct', '40-44', '35-39', '9-May', '45-49']
inv_nodes_values = ['0-2', '8-Jun', '11-Sep', '5-Mar', '15-17', '14-Dec', '24-26'] 
node_caps_values = ['no', 'yes']
deg_malig_values = [1, 2, 3]
breast_values = ['left', 'right']
breast_quad_values = ['left_low', 'right_up', 'left_up', 'central', 'right_low']
irradiat_values = ['no', 'yes']


# All possible combinations
combinations = list(itertools.product(age_values, 
                                      menopause_values, 
                                      tumor_size_values, 
                                      inv_nodes_values, 
                                      node_caps_values, 
                                      deg_malig_values,
                                      breast_values,
                                      breast_quad_values,
                                      irradiat_values))

# %%
depths = []

for comb in tqdm(combinations):
    #creating delta
    delta = pd.DataFrame(
    [[comb[0], comb[1], comb[2], comb[3], comb[4], comb[5], comb[6], comb[7], comb[8]]],
    columns=['age',
             'menopause',
             'tumor-size',
             'inv-nodes', 
             'node-caps', 
             'deg-malig',
             'breast',
             'breast-quad',
             'irradiat'])
    
    delta = delta.loc[0]
    
    alg = A_C_N(C="AD", N="greedy")
    
    depth, _ = alg.solve(S, delta=delta)
    
    depths.append(depth)
# Out:
#   0%|                                   | 15/166320 [00:46<142:50:09,  3.09s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#      17 delta = delta.loc[0]
#      19 alg = A_C_N(C="AD", N="greedy")
# ---> 21 depth, _ = alg.solve(S, delta=delta)
#      23 depths.append(depth)
#
# File ~/Desktop/DrDt/drdt/algorithms.py:192, in A_C_N.solve(self, S, delta)
#     189                 Q = S.copy()
#     190                 while True:
#     191                     # Step 1
# --> 192                     P = self.R_C(Q)
#     193                     if (P.empty or P.iloc[:, :-1].isna().all().all()):
#     194                         if P.empty:
#     195 #                             print("There is no such rule")
#
# File ~/Desktop/DrDt/drdt/helper_functions.py:60, in R_AD(S)
#      58 if i in to_remove or j in to_remove:
#      59     continue
# ---> 60 r1, r2 = S.iloc[i], S.iloc[j]
#      62 if all(pd.isna(r1[k]) or r1[k] == r2[k] for k in S.columns):
#      63     to_remove.add(j)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1522, in _iLocIndexer._getitem_axis(self, key, axis)
#    1519 # validate the location
#    1520 self._validate_integer(key, axis)
# -> 1522 return self.obj._ixs(key, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3428, in DataFrame._ixs(self, i, axis)
#    3426 # if we are a copy, mark as such
#    3427 copy = isinstance(new_values, np.ndarray) and new_values.base is None
# -> 3428 result = self._constructor_sliced(
#    3429     new_values,
#    3430     index=self.columns,
#    3431     name=self.index[i],
#    3432     dtype=new_values.dtype,
#    3433 )
#    3434 result._set_is_copy(self, copy=copy)
#    3435 return result
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:451, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     449         data = data.copy()
#     450 else:
# --> 451     data = sanitize_array(data, index, dtype, copy)
#     453     manager = get_option("mode.data_manager")
#     454     if manager == "block":
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/construction.py:533, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     530 if isinstance(data, np.matrix):
#     531     data = data.A
# --> 533 if dtype is not None and is_float_dtype(data.dtype) and is_integer_dtype(dtype):
#     534     # possibility of nan -> garbage
#     535     try:
#     536         subarr = _try_cast(data, dtype, copy, True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/common.py:1271, in is_float_dtype(arr_or_dtype)
#    1240 def is_float_dtype(arr_or_dtype) -> bool:
#    1241     """
#    1242     Check whether the provided array or dtype is of a float dtype.
#    1243
#    (...)
#    1269     True
#    1270     """
# -> 1271     return _is_dtype_type(arr_or_dtype, classes(np.floating))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/common.py:1606, in _is_dtype_type(arr_or_dtype, condition)
#    1604 # fastpath
#    1605 if isinstance(arr_or_dtype, np.dtype):
# -> 1606     return condition(arr_or_dtype.type)
#    1607 elif isinstance(arr_or_dtype, type):
#    1608     if issubclass(arr_or_dtype, ExtensionDtype):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/dtypes/common.py:147, in classes.<locals>.<lambda>(tipo)
#     145 def classes(*klasses) -> Callable:
#     146     """Evaluate if the tipo is a subclass of the klasses."""
# --> 147     return lambda tipo: issubclass(tipo, klasses)
#
# KeyboardInterrupt:

# %%
print("(Max Depth, Min Depth, Average Depth) =", (max(depths), min(depths), sum(depths)/len(depths)))
